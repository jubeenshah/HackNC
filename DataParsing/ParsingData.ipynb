# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import matplotlib.mlab as mlab
import statistics
import math
import collections
import json
import csv

# %%
foodData = pd.read_csv("/Users/jubeenshah/Desktop/Development/HackathonsData/HackNC_Data/Data/RAW_recipes.csv")

# %%
foodData.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# ...

# %%
(foodData["steps"])
# Out:
# 0         ['make a choice and proceed with recipe', 'dep...
# 1         ['preheat oven to 425 degrees f', 'press dough...
# 2         ['brown ground beef in large pot', 'add choppe...
# 3         ['place potatoes in a large pot of lightly sal...
# 4         ['mix all ingredients& boil for 2 1 / 2 hours ...
# 5         ['combine ingredients in blender', 'cover and ...
# 6         ['toast the fennel seeds and lightly crush the...
# 7         ['in a medium saucepan combine all the ingredi...
# 8         ['crumble cookies into a 9-inch pie plate , or...
# 9         ['preheat oven to 350 degrees', 'butter two 9x...
# 10        ['in medium size bowl , coarsely mash cranberr...
# 11        ['crush vanilla wafers into fine crumbs and li...
# 12        ['in a very large sauce pan cover the beans an...
# 13        ['put prepared greens in large pot', 'add wate...
# 14        ['combine herbs', 'dosage: one-half teaspoonfu...
# 15        ['dredge pork chops in mixture of flour , salt...
# ...

# %%
foodData['ingredients'][0]
# Out:
# "['winter squash', 'mexican seasoning', 'mixed spice', 'honey', 'butter', 'olive oil', 'salt']"

# %%
foodData['nutrition'][0]
# Out:
# '[51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]'

# %%
foodData['tags'][0]
# Out:
# "['60-minutes-or-less', 'time-to-make', 'course', 'main-ingredient', 'cuisine', 'preparation', 'occasion', 'north-american', 'side-dishes', 'vegetables', 'mexican', 'easy', 'fall', 'holiday-event', 'vegetarian', 'winter', 'dietary', 'christmas', 'seasonal', 'squash']"

# %% [markdown]
# sample_dataframe = foodData.sample(n=69491)

# %%
sample_dataframe = foodData.sample(n=10000)
sample_dataframe.to_csv("/Users/jubeenshah/Desktop/Development/HackathonsData/HackNC_Data/Data/RAW_recipes_sample_10000.csv", encoding='utf-8', index=False)

# %%
f = open( '/Users/jubeenshah/Desktop/Development/HackathonsData/HackNC_Data/Data/RAW_recipes_sample_10000.csv', 'rU' )  

reader = csv.DictReader( f, fieldnames = ( "name","id","minutes","contributor_id","submitted","tags","nutrition","n_steps","steps","description","ingredients","n_ingredients"))  

out = json.dumps( [ row for row in reader ] )  
print ("JSON parsed!") 

f = open( '/Users/jubeenshah/Desktop/Development/HackathonsData/HackNC_Data/Data/RAW_recipes_sample_10000.json', 'w')  
f.write(out)  
print ("JSON saved!")
# Out:
# /Users/jubeenshah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: 'U' mode is deprecated
# JSON parsed!
# JSON saved!

# %%
listToCheckReviews = list(sample_dataframe["id"])

# %%
foodData.loc[foodData['id'].isin([21312])].head()
# Out:
# Empty DataFrame
# Columns: [name, id, minutes, contributor_id, submitted, tags, nutrition, n_steps, steps, description, ingredients, n_ingredients]
# Index: []

# %%
foodData.sample(n=1)
# Out:
#                                              name      id  minutes  \
# 96662  greek potato salad with sun dried tomatoes  170761       55
#
#        contributor_id   submitted  \
# 96662          269521  2006-05-30
#
#                                                     tags  \
# 96662  ['60-minutes-or-less', 'time-to-make', 'course...
#
#                                         nutrition  n_steps  \
# 96662  [194.4, 18.0, 24.0, 29.0, 10.0, 19.0, 6.0]       13
#
#                                                    steps  \
# 96662  ['place in potatoes in 2 quart saucepan', 'add...
#
#                                              description  \
# 96662  found this recipe on the internet, can't remem...
#
#                                              ingredients  n_ingredients
# 96662  ['small red potato', 'sun-dried tomato', 'seed...             14

# %%
reviewsData = pd.read_csv("/Users/jubeenshah/Desktop/Development/HackathonsData/HackNC_Data/Data/RAW_interactions.csv")

# %%
reviewsData.head()
# Out:
#    user_id  recipe_id        date  rating  \
# 0    38094      40893  2003-02-17       4
# 1  1293707      40893  2011-12-21       5
# 2     8937      44394  2002-12-01       4
# 3   126440      85009  2010-02-27       5
# 4    57222      85009  2011-10-01       5
#
#                                               review
# 0  Great with a salad. Cooked on top of stove for...
# 1  So simple, so delicious! Great for chilly fall...
# 2  This worked very well and is EASY.  I used not...
# 3  I made the Mexican topping and took it to bunk...
# 4  Made the cheddar bacon topping, adding a sprin...

# %%
#for recipeId in listToCheckReviews:

# %%
col_names =  ["user_id", "recipe_id" ,"date", "rating" ,"review"]
sampledReviews = pd.DataFrame(columns = col_names)
sampledReviews
# Out:
# Empty DataFrame
# Columns: [user_id, recipe_id, date, rating, review]
# Index: []

# %%
sampledReviews.head()
# Out:
# Empty DataFrame
# Columns: [user_id, recipe_id, date, rating, review]
# Index: []

# %%
listToCheckReviews
# Out:
# [35958,
#  91984,
#  166965,
#  101843,
#  221926,
#  482972,
#  255307,
#  165157,
#  369117,
#  159913,
#  480010,
#  496772,
#  390803,
#  159547,
#  216198,
#  25699,
#  69443,
#  417814,
#  150131,
#  277297,
#  282915,
#  341088,
#  237016,
#  185836,
#  24507,
#  477042,
#  82931,
#  130017,
#  192464,
#  461701,
#  84244,
#  455201,
#  475083,
#  204643,
#  465597,
#  175672,
#  32340,
#  71005,
#  190558,
#  337542,
#  41795,
#  263307,
#  169103,
#  531159,
#  171702,
#  59043,
#  100127,
#  429952,
#  107930,
#  19111,
#  355120,
#  86982,
#  171626,
#  262218,
#  236341,
#  458179,
#  332100,
#  336869,
#  111587,
#  287997,
#  29846,
#  334997,
#  148023,
#  51549,
#  13608,
#  191941,
#  66169,
#  222289,
#  336955,
#  69347,
#  188909,
#  50980,
#  285516,
#  436697,
#  448521,
#  295835,
#  168698,
#  262430,
#  428376,
#  195254,
#  487210,
#  168166,
#  165253,
#  358237,
#  72188,
#  132035,
#  364149,
#  327904,
#  57518,
#  262386,
#  448766,
#  345346,
# ...

# %%
reviewsData[reviewsData['recipe_id'].isin([259937,88453])].to_csv()
# Out:
# ',user_id,recipe_id,date,rating,review\n11952,39835,88453,2004-05-31,5,Delicious -- this sauce is fantastic and the chicken was great! We used a spicer chili sauce than mentioned with fantastic results! Thanks for sharing!\n11953,101823,88453,2004-06-15,5,"This chicken was incredibly succulent. I was missing celery seeds, and therefore subbed celery salt for the seeds and salt required in the recipe. I also increased the hot pepper sauce slightly. I prepared this with boneless, skinless chicken breasts, and basted very frequently while grilling. Without the skin and bones, my grilling time was naturally shorter. My hubby loved the flavor of this sauce and liked that I had reserved some for dipping the finished chicken. I also roasted corn on the cob, tossed a salad and made Grilled Ranch Bread (recipe#93249) for a complete meal. It was delicious and perfect for a summer evening.\r\nUPDATE***The next evening, I had some pork loin chops defrosted for dinner.  When I asked Hubby how he 
# ...

# %%
sampled_review = reviewsData[reviewsData['recipe_id'].isin(listToCheckReviews)].sample(n=30000)

# %%
collections.Counter(sampled_review['recipe_id'])
# Out:
# Counter({94098: 3,
#          202092: 4,
#          21178: 27,
#          165490: 3,
#          112365: 11,
#          32880: 46,
#          410794: 1,
#          32844: 262,
#          13413: 1,
#          154885: 1,
#          82778: 9,
#          115676: 9,
#          216434: 6,
#          64685: 5,
#          110077: 33,
#          101514: 6,
#          207702: 7,
#          53066: 3,
#          108598: 2,
#          45515: 6,
#          39369: 48,
#          383189: 3,
#          100770: 15,
#          257962: 11,
#          28970: 7,
#          162750: 5,
#          21284: 40,
#          37425: 43,
#          165429: 10,
#          15865: 236,
#          34499: 183,
#          14677: 1,
#          37455: 40,
#          348802: 100,
#          245581: 8,
#          322107: 9,
#          316064: 1,
#          160925: 10,
#          296684: 3,
#          171095: 4,
#          200296: 255,
#          367677: 8,
#          60542: 8,
#          305883: 10,
#          51007: 3,
# ...

# %%
sampled_review=sampled_review.sort_values(by=["recipe_id"])
sampled_review.head()
# Out:
#            user_id  recipe_id        date  rating  \
# 610134      796628        224  2008-10-08       5
# 610138  2002060916        224  2018-03-18       0
# 610135      437237        224  2009-03-29       5
# 610133      926187        224  2008-08-24       5
# 610137      383346        224  2013-10-30       5
#
#                                                    review
# 610134  An excellent recipe. I did change a few things...
# 610138  What a waste of ingredients. After trying one ...
# 610135  I did omit the coffee, I don't have instant in...
# 610133  Nice change of pace from vanilla.  I chopped u...
# 610137  I like tapioca pudding and this one is so diff...

# %%
sampled_review.to_csv("/Users/jubeenshah/Desktop/Development/HackathonsData/HackNC_Data/Data/RAW_interactions_sample_25000.csv", encoding='utf-8', index=False)

# %%
f = open( '/Users/jubeenshah/Desktop/Development/HackathonsData/HackNC_Data/Data/RAW_interactions_sample_25000.csv', 'rU' )  

reader = csv.DictReader( f, fieldnames = ( "user_id","recipe_id","date","rating", "review"))  

out = json.dumps( [ row for row in reader ] )  
print ("JSON parsed!") 

f = open( '/Users/jubeenshah/Desktop/Development/HackathonsData/HackNC_Data/Data/RAW_interactions_sample_25000.json', 'w')  
f.write(out)  
print ("JSON saved!")
# Out:
# /Users/jubeenshah/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: 'U' mode is deprecated
# JSON parsed!
# JSON saved!

# %%
text = "['make a choice and proceed with recipe', 'depending on size of squash , cut into half or fourths', 'remove seeds', 'for spicy squash , drizzle olive oil or melted butter over each cut squash piece', 'season with mexican seasoning mix ii', 'for sweet squash , drizzle melted honey , butter , grated piloncillo over each cut squash piece', 'season with sweet mexican spice mix', 'bake at 350 degrees , again depending on size , for 40 minutes up to an hour , until a fork can easily pierce the skin', 'be careful not to burn the squash especially if you opt to use sugar or butter', 'if you feel more comfortable , cover the squash with aluminum foil the first half hour , give or take , of baking', 'if desired , season with salt']"

# %%
print((text))
# Out:
# ['make a choice and proceed with recipe', 'depending on size of squash , cut into half or fourths', 'remove seeds', 'for spicy squash , drizzle olive oil or melted butter over each cut squash piece', 'season with mexican seasoning mix ii', 'for sweet squash , drizzle melted honey , butter , grated piloncillo over each cut squash piece', 'season with sweet mexican spice mix', 'bake at 350 degrees , again depending on size , for 40 minutes up to an hour , until a fork can easily pierce the skin', 'be careful not to burn the squash especially if you opt to use sugar or butter', 'if you feel more comfortable , cover the squash with aluminum foil the first half hour , give or take , of baking', 'if desired , season with salt']

# %%
import re

# %%
a = re.findall(r"'(.*?)'", text)
a[0]
# Out:
# 'make a choice and proceed with recipe'

# %%
x = [re.findall(r"'(.*?)'", x) for x in sample_dataframe["tags"]]

# %%
emptyList = []
for eachArray in x:
    for eachElement in eachArray:
        emptyList.append(eachElement)

# %%
tagsList = (dict(collections.Counter(emptyList)))

# %%
test ="['make a choice and proceed with recipe', 'depending on size of squash , cut into half or fourths', 'remove seeds', 'for spicy squash , drizzle olive oil or melted butter over each cut squash piece', 'season with mexican seasoning mix ii', 'for sweet squash , drizzle melted honey , butter , grated piloncillo over each cut squash piece', 'season with sweet mexican spice mix', 'bake at 350 degrees , again depending on size , for 40 minutes up to an hour , until a fork can easily pierce the skin', 'be careful not to burn the squash especially if you opt to use sugar or butter', 'if you feel more comfortable , cover the squash with aluminum foil the first half hour , give or take , of baking', 'if desired , season with salt']"

# %%
test.split("', '")
# Out:
# ["['make a choice and proceed with recipe",
#  'depending on size of squash , cut into half or fourths',
#  'remove seeds',
#  'for spicy squash , drizzle olive oil or melted butter over each cut squash piece',
#  'season with mexican seasoning mix ii',
#  'for sweet squash , drizzle melted honey , butter , grated piloncillo over each cut squash piece',
#  'season with sweet mexican spice mix',
#  'bake at 350 degrees , again depending on size , for 40 minutes up to an hour , until a fork can easily pierce the skin',
#  'be careful not to burn the squash especially if you opt to use sugar or butter',
#  'if you feel more comfortable , cover the squash with aluminum foil the first half hour , give or take , of baking',
#  "if desired , season with salt']"]

# %%
len(tagsList)
# Out:
# 481

# %%
for index, value in enumerate(tagsList):
    print(value)
# Out:
# 60-minutes-or-less
# time-to-make
# course
# main-ingredient
# preparation
# occasion
# desserts
# fruit
# easy
# cookies-and-brownies
# bar-cookies
# dietary
# low-sodium
# comfort-food
# low-in-something
# taste-mood
# number-of-servings
# cuisine
# rice
# asian
# middle-eastern
# dinner-party
# vegan
# vegetarian
# turkish
# pasta-rice-and-grains
# white-rice
# szechuan
# lunch
# main-dish
# pork
# chinese
# beginner-cook
# holiday-event
# inexpensive
# meat
# for-1-or-2
# soups-stews
# potatoes
# vegetables
# fall
# winter
# copycat
# seasonal
# low-calorie
# low-carb
# novelty
# 4-hours-or-less
# low-protein
# beef
# crock-pot-slow-cooker
# equipment
# weeknight
# 15-minutes-or-less
# beverages
# australian
# citrus
# lemon
# tropical-fruit
# kiwifruit
# 3-steps-or-less
# non-alcoholic
# for-large-groups
# 5-ingredients-or-less
# gelatin
# cakes
# lactose
# north-american
# very-low-carbs
# canadian
# free-of-something
# brunch
# healthy
# low-fat
# summer
# low-cholesterol
# ...

# %%
if "keto" in tagsList:
    print("true")

# %%
foodData = testDf = pd.read_csv("/Users/jubeenshah/Desktop/Development/HackathonsData/HackNC_Data/Data/RAW_interactions_sample_25000.csv")

# %%
len(testDf)
# Out:
# 30000
